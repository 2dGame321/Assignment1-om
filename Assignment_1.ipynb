# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

import plotly.express as px
from sklearn.preprocessing import MinMaxScaler

# %%
df = pd.read_csv("StudentPerformanceFactors.csv.xls")
df
# Out:
#       Hours_Studied  Attendance  ...  Gender Exam_Score
# 0              23.0          84  ...    Male         67
# 1              19.0          64  ...  Female         61
# 2              24.0          98  ...    Male         74
# 3              29.0          89  ...    Male         71
# 4              19.0          92  ...  Female         70
# ...             ...         ...  ...     ...        ...
# 6602           25.0          69  ...  Female         68
# 6603           23.0          76  ...  Female         69
# 6604           20.0          90  ...  Female         68
# 6605           10.0          86  ...  Female         68
# 6606           15.0          67  ...    Male         64
#
# [6607 rows x 20 columns]

# %%
a = df.loc[df["Exam_Score"]<65]
a
# Out:
#       Hours_Studied  Attendance  ...  Gender Exam_Score
# 1              19.0          64  ...  Female         61
# 15              NaN          68  ...  Female         64
# 16             14.0          60  ...    Male         60
# 24             17.0          65  ...  Female         63
# 25             21.0          62  ...    Male         64
# ...             ...         ...  ...     ...        ...
# 6578           22.0          76  ...  Female         64
# 6583           11.0          67  ...  Female         63
# 6593           16.0          75  ...  Female         64
# 6598            9.0          87  ...  Female         64
# 6606           15.0          67  ...    Male         64
#
# [1452 rows x 20 columns]

# %%
b = df.loc[df["Attendance"]>=90]
b
# Out:
#       Hours_Studied  Attendance  ...  Gender Exam_Score
# 2              24.0          98  ...    Male         74
# 4              19.0          92  ...  Female         70
# 8              17.0          94  ...    Male         69
# 9              23.0          98  ...    Male         72
# 11             17.0          97  ...    Male         71
# ...             ...         ...  ...     ...        ...
# 6596           17.0          92  ...    Male         66
# 6597           16.0          91  ...  Female         70
# 6599           30.0          94  ...  Female         70
# 6600           12.0          98  ...  Female         67
# 6604           20.0          90  ...  Female         68
#
# [1746 rows x 20 columns]

# %%
c = df.iloc[42:55]
c
# Out:
#     Hours_Studied  Attendance  ...  Gender Exam_Score
# 42           19.0          63  ...    Male         64
# 43           18.0          94  ...    Male         70
# 44           11.0          98  ...    Male         68
# 45           16.0          70  ...    Male         65
# 46           17.0          78  ...  Female         68
# 47           26.0          61  ...  Female         64
# 48           22.0          86  ...    Male         68
# 49            9.0          77  ...    Male         63
# 50           22.0          71  ...    Male         64
# 51           18.0          68  ...    Male         64
# 52            NaN          86  ...    Male         67
# 53           24.0          77  ...  Female         67
# 54           26.0          67  ...  Female         66
#
# [13 rows x 20 columns]

# %%
min = df["Hours_Studied"].min()
max = df["Hours_Studied"].max()

print(min,max)
# Out:
# 1.0 44.0

# %%
df["Hours_Studied"].fillna(df["Hours_Studied"].median(),inplace=True)
df
# Out:
# /tmp/ipython-input-4063987549.py:1: FutureWarning:
#
# A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#       Hours_Studied  Attendance  ...  Gender Exam_Score
# 0              23.0          84  ...    Male         67
# 1              19.0          64  ...  Female         61
# 2              24.0          98  ...    Male         74
# 3              29.0          89  ...    Male         71
# 4              19.0          92  ...  Female         70
# ...             ...         ...  ...     ...        ...
# ...

# %%
nullValue = df[df.isnull().any(axis=1)]
nullValue
# Out:
#       Hours_Studied  Attendance  ...  Gender Exam_Score
# 33             14.0          60  ...  Female         61
# 127            17.0          97  ...    Male         69
# 240            15.0          87  ...    Male         65
# 275            23.0          82  ...    Male         66
# 316            24.0          90  ...    Male         68
# ...             ...         ...  ...     ...        ...
# 6502           23.0          64  ...  Female         66
# 6579            9.0          84  ...    Male         67
# 6589           22.0          90  ...  Female         70
# 6594            9.0          90  ...    Male         70
# 6596           17.0          92  ...    Male         66
#
# [229 rows x 20 columns]

# %%
plt.hist(df["Access_to_Resources"].dropna(),bins=5)
plt.title("Resource are helpfull for student(bar Graph)")
plt.xlabel("Access_to_Resource")
plt.ylabel("Exam_Score")
plt.show()

# %%
y_data = df["Exam_Score"]
x_data = df["Motivation_Level"]
plt.plot(x_data,y_data,linestyle='-')
plt.title("how to motivation level helpfull for student")
plt.xlabel("Exam_Score")
plt.ylabel("Motivation_Level")
plt.show()

# %%
box = px.box(df,y="Exam_Score",title="Box plot for Exam Score")
box.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
boxplot = px.box(df,y="Hours_Studied",title="Box plot for hours studied ")
boxplot.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df1 =df.copy()

df1["Hours_Studied"].fillna(df1["Hours_Studied"].median(),inplace=True)
df1.iloc[15]
# Out:
# /tmp/ipython-input-2449480729.py:3: FutureWarning:
#
# A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
# Hours_Studied                        20.0
# Attendance                             68
# Parental_Involvement               Medium
# Access_to_Resources                Medium
# Extracurricular_Activities             No
# Sleep_Hours                             8
# Previous_Scores                        70
# Motivation_Level                   Medium
# Internet_Access                       Yes
# Tutoring_Sessions                       2
# ...

# %%
df2 = df.copy()

df2["Teacher_Quality"].fillna(method="bfill",inplace=True)
df2
# Out:
# /tmp/ipython-input-130277774.py:3: FutureWarning:
#
# A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#
# /tmp/ipython-input-130277774.py:3: FutureWarning:
#
# Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#       Hours_Studied  Attendance  ...  Gender Exam_Score
# 0              23.0          84  ...    Male         67
# 1              19.0          64  ...  Female         61
# 2              24.0          98  ...    Male         74
# ...

# %%
df3 = df.copy()

df3["Parental_Education_Level"].fillna(method="ffill",inplace=True)
df3.iloc[242]
# Out:
# /tmp/ipython-input-4269365910.py:3: FutureWarning:
#
# A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#
# /tmp/ipython-input-4269365910.py:3: FutureWarning:
#
# Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
# Hours_Studied                        23.0
# Attendance                             61
# Parental_Involvement                  Low
# Access_to_Resources                Medium
# Extracurricular_Activities             No
# ...

# %%
df4 = df1.copy()
scaler = MinMaxScaler()
df4["Housr_st_norm"] = scaler.fit_transform(df1[["Hours_Studied"]])
df4
# Out:
#       Hours_Studied  Attendance  ... Exam_Score Housr_st_norm
# 0              23.0          84  ...         67      0.511628
# 1              19.0          64  ...         61      0.418605
# 2              24.0          98  ...         74      0.534884
# 3              29.0          89  ...         71      0.651163
# 4              19.0          92  ...         70      0.418605
# ...             ...         ...  ...        ...           ...
# 6602           25.0          69  ...         68      0.558140
# 6603           23.0          76  ...         69      0.511628
# 6604           20.0          90  ...         68      0.441860
# 6605           10.0          86  ...         68      0.209302
# 6606           15.0          67  ...         64      0.325581
#
# [6607 rows x 21 columns]

# %%
box = px.box(df4,y="Housr_st_norm",title="Box Plot Of Hours Studies Normalization")
box.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
